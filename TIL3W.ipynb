# %% [markdown]
# > **Chapter 11.** 웹 페이지 구성하기
#
# head안에는 title넣을 수 있고, 폰트를 변경할 수 있다.
#
# body<br>
# nav 이용 : 현재 페이지 내에서나 다른 페이지 내로의 링크를 보여주는 것
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# header : 첫 페이지에서 바로 보이는 부분
#
# section : 분할해서 보여지는 부분
#
# footer : 페이지 밑 부분
#
# > **Chapter 12.** CSS 라이브러리 활용하기 - TailwindCSS
#
# TailwindCSS란? : 간단하게 css 속성을 적용할 수 있는 것!!<br>
# 기본코드가 주어지기 때문에 더욱 섬세한 디자인을 할 수 있다.<br>
# 변수명을 정하는데 시간을 쓰지 않아도 된다<br>
# 미리 세팅된 유틸리티 클래스를 활용하는 방식으로 HTML 코드 내에서 스타일링을 할 수 있다.<br>
# 쉽고 빠른 개발 가능!<br>
