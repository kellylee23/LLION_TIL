# %% [markdown]
# **Chapter 7** 컴포넌트를 그리는 여러가지 방법: Component render
#
# - 컴포넌트 리스트의 필요성 : 겹치는 내용의 코드를 복사, 붙여넣기를 계속 한다면 효율성이 좋지 않기 때문에 컴포넌트 리스트를 사용한다.
#
# - 맵 함수 이용 : 배열을 이용해서 배열을 맵 함수로 받는다.
# 배열의 원소를 출력 -> 콜백 -> 실행 -> 다시 배열로 받는다.
#
# - 키값 : 배열의 아이템, 고유한 값!, 변화하는 값이면 안된다. 중괄호 이용
#
# - ![스크린샷 2024-07-03 224635.png](<attachment:스크린샷 2024-07-03 224635.png>)
#
# - 조건에 따라 다른 페이지 랜더링 : props를 조건으로 받을 때, 조건에 따라(if문) props를 출력할 수도, 아니면 다른 값을 return 할 수도 있다.
#
# - 상태관리와 이벤트 실습 : <Form> </Form> : 입력된 데이터를 한 번에 서버로 전송한다.
#
# - ![image.png](attachment:image.png)
#
# - 사용자가 이름, 종, 나이를 입력하면 이러한 고유한 값들이 반환된다.

# %% [markdown]
# **Chapter 8**
# UI를 꾸며보기: React styling
#
# - css module : 선택자 우선순위가 적용된다.
#
# - 각각의 부모요소, 자식요소를 잘 확인해야 한다. -> 뭐를 적용하는지 잘 알아야하기 때문에
#
# - styled-components : 가장 인기있는 리액트 라이브러리
#
# - -> 글로벌스타일 : styled-components가 제공하는 createGlobalStyle()함수 -> 기본 틀 만드는 것.
#
# - --> const GlobalStyled = createGlobalStyle`
#
#     - const 다음에 대문자로 시작
#
#     - css에서 사용하는 문법 그대로 사용
#
#     - css, js함께 사용가능
#
#     - props 전달 가능

# %% [markdown]
# **Chapter 9** 프로젝트

# %% [markdown]
# const Button = styled.Button`
#
# background-color: bule;
# padding: 10px;
# color: white;
# `
#
# const Button2 = styled(Button)`
# color:black;
# border:none;
# border-radius:10px;
# font-weight: bold;
# box-shadow: 0px 0px 2px 2px rgba(0,0,0,0.3);
# `
#
# const Button3 = styled(Button)`
# border:none;
# border-radius:20px;
# background-color: lightgreen;
# box-shadow: 0px 0px 2px 2px rgba(0,0,0,0.3);
# `
# export { Button, Button2, Button3}
#
#
# -> 첫 번째 버튼 css를 가져옴
