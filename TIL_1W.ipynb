# %% [markdown]
# ### ch 2, 3, 6, 7
#
# > ch2
#
# 1. 웹
#
#     - 개방되어 있다.
#     - 속도가 빠르다.
#     - 광랜
#
# 2. 프로토콜, https
#
#     - host : 서버 주소
#     - path : 서비스 별 분할
#     - 쿼리 문자열 : ?기호로 시작, &로 연결
#     - http는 보안이 없고, https는 보안이 있다.
# 3. port & DNS
#
#     - 서비스를 구분하는 역할
#     - 접근하려는 서비스의 목적지 포트를 정확하게 설정해야 한다.
#     - 국가, 기업 등이 운영
#     - 전세계 DNS는 연결되어 있다.
#     - 장애 발생 시. 막대한 피해 있음.
#
# > ch3
#
# - HTML: 구조/내용, 여는 태그, 닫는태그 필요
# - CSS: 모양/스타일, 웹 꾸며주는 것
# - JS : 이벤트/반응, 웹 꾸미는 것을 더 풍부하게..!!
#
#
# > ch6,7

# %%
1. heading 태그는 글씨를 키우려는 목적으로 사용하는 것이 아님. -> 부제목 및 대제목을 부여하는 의미!
2. <br>태그-> 줄바꿈, 단일 태그이다. 닫는태그 없음
3. <p> 문단
4. <ol> 순서를 매김
    -> <li>:하나하나의 요소, 자동으로 순서 !!
    -> <ul> 순서 없이 매김  
5. <a href="연결할 링크"> </a>
6. <span> 문자열 일부를 요소처럼 조작 
7. <div> 태그들을 하나의 요소처럼 조작
8.  주석 -> ctrl + /
9.  a href="#"은 url 하이퍼링크는 생겼지만, 실제로는 링크로 이동하지 않음 -> 링크가 없어서
10. formating : 우측버튼 누르고 format document누르기
- <og tag> : meta에 넣어서 배포 시, 사진 및 제목 부제목을 넣을 수 있음.
