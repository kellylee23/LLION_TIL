# %% [markdown]
# >**Chapter 13.** JavaScript Beginner
#
# 자바스크립트 마지막에 세미콜론을 붙여야한다.<br>
# script src="~~~.js" -> 외부의 자바스크립트 파일을 불러와준다.<br>
# 자바스크립트 주석처리 방법<br>
# ![image.png](attachment:image.png)

# %%
// 변수 선언
var num;

// 변수 초기화
num = 10;

//변수 선언+초기화
var num =10;
num =20;

console.log(num);

//사용할 수없는 변수명
/* 
1. 숫자로 시작하는 것
2. 특수문자로 시작하는 것들!
*/

# %% [markdown]
# ***자료형***
#
# 1. 기본형, 단순형, 원시형
#     - number
#     - string
#     - boolean
#     - undefined
#     - null
#     - symbol
#
#
# - number<br>
# 정수(integer), 실수 구분이 없음<br>
# var price = 10000;
#
# - string<br>
# var myname = "테킷";<br>
# var myname2 = '멋사';
#
# - boolean<br>
# var isTrue = True;<br>
# var isFalse = false;
#
# - undefined<br>
# var a;

# %% [markdown]
# ***객체***
#
#
# var student = {
#     grade: 1,
#     school: "lion school"
# };
#
#
# - 객체의 값 호출<br>
# var gradeInfo = student.grade;<br>
# console.log(gradeInfo);
#
#
# - 객체의 키 호출<br>
# var key = Object.keys(student)[0];<br>
# console.log(key);

# %% [markdown]
# ***연산자***
# 1. 산술연산자(덧셈, 뺄셈, 나눗셈, 곱셉....)
# 2. 대입연산자, 할당연산자
# 3. 비교연산자(==, ===, !=, !==, <, >)

# %% [markdown]
# ***에러처리***

# %%
try{
    
    // 에러가 발생할 가능성이 있는 코드
    throw new Error("error");

} catch(){
    
    //에러가 발생했을 때 실행되는 코드
    console.log("error!");
    console.log(error);

} finally{

    //에러 발생여부와 상관없이 무조건 실행
    console.log("무조건실행");
}
# Out:
#   Cell In[2], line 1
#     try{
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# >**Chapter 14.** JavaScript Next Level
#
# dom => 이벤트를 실행하기 위한 !
#
# event ex)<br>
# * 폼이벤트
#     - 제출, 초기화
# * 마우스 이벤트
#     - 클릭, 더블클릭, 마우스 이동
# * 키보드 이벤트
#     - keydown, keypress, keyup
#
# on + 이벤트 타입
#
# onclick ="alert('click!');"
